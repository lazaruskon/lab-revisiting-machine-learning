# %% [markdown]
# # Unit 7 Lab | Revisiting Machine Learning Case Study

# %% [markdown]
# ## Importing Libraries & Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("learningSetLaz.csv", low_memory=False)
df
# Out:
#        ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0         8901     GRI      0    IL  61081                    3712      0
# 1         9401     BOA      1    CA  91326                    5202      0
# 2         9001     AMH      1    NC  27017                       0      0
# 3         8701     BRY      0    CA  95953                    2801      0
# 4         8601              0    FL  33176                    2001      0
# ...        ...     ...    ...   ...    ...      ...      ...   ...    ...
# 95407     9601     ASE      1    AK  99504                       0      0
# 95408     9601     DCD      1    TX  77379                    5001      0
# 95409     9501     MBC      1    MI  48910                    3801      0
# 95410     8601     PRV      0    CA  91320                    4005      0
# 95411     8801     MCC      2    NC  28409                    1801      0
#
#       RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# ...

# %%
df.columns
# Out:
# Index(['ODATEDW', 'OSOURCE', 'TCODE', 'STATE', 'ZIP', 'MAILCODE', 'PVASTATE',
#        'DOB', 'NOEXCH', 'RECINHSE',
#        ...
#        'TARGET_D', 'HPHONE_D', 'RFA_2R', 'RFA_2F', 'RFA_2A', 'MDMAUD_R',
#        'MDMAUD_F', 'MDMAUD_A', 'CLUSTER2', 'GEOCODE2'],
#       dtype='object', length=481)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95412 entries, 0 to 95411
# Columns: 481 entries, ODATEDW to GEOCODE2
# dtypes: float64(97), int64(310), object(74)
# memory usage: 350.1+ MB

# %%
categorical = df.select_dtypes(include=['object'])
categorical
# Out:
#       OSOURCE STATE    ZIP MAILCODE PVASTATE NOEXCH RECINHSE RECP3 RECPGVG  \
# 0         GRI    IL  61081                        0
# 1         BOA    CA  91326                        0
# 2         AMH    NC  27017                        0
# 3         BRY    CA  95953                        0
# 4                FL  33176                        0        X     X
# ...       ...   ...    ...      ...      ...    ...      ...   ...     ...
# 95407     ASE    AK  99504                        0
# 95408     DCD    TX  77379                        0
# 95409     MBC    MI  48910                        0              X
# 95410     PRV    CA  91320                        0        X
# 95411     MCC    NC  28409                        0        X             X
#
#       RECSWEEP  ... RFA_21 RFA_22 RFA_23 RFA_24 RFA_2R RFA_2A MDMAUD_R  \
# 0               ...    S4E    S4E    S4E    S4E      L      E        X
# 1               ...    N1E    N1E           F1E      L      G        X
# ...

# %% [markdown]
# ### Check for null values in all the columns

# %%
df.isna().sum()
# Out:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2    132
# Length: 481, dtype: int64

# %%
categorical.isna().sum()
# Out:
# OSOURCE       0
# STATE         0
# ZIP           0
# MAILCODE      0
# PVASTATE      0
#            ...
# RFA_2A        0
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# GEOCODE2    132
# Length: 74, dtype: int64

# %% [markdown]
# ### Exclude the following variables by looking at the definitions. Create a new empty list called drop_list. We will append this list and then drop all the columns in this list later:
#
#    - `OSOURCE` - symbol definitions not provided, too many categories
#    - `ZIP CODE` - we are including state already

# %%
# I'm not sure I understand what this question want me to exactly so I'm appending to this list 
#but I'll save the data we're dropping in a separate dataframe too.

drop_list = []

drop_list.append(["OSOURCE", "ZIP"])
drop_list
# Out:
# [['OSOURCE', 'ZIP']]

# %%
df_drop = df[["OSOURCE", "ZIP"]].copy()
df_drop
#back-up dataframe for dropped columns
# Out:
#       OSOURCE    ZIP
# 0         GRI  61081
# 1         BOA  91326
# 2         AMH  27017
# 3         BRY  95953
# 4              33176
# ...       ...    ...
# 95407     ASE  99504
# 95408     DCD  77379
# 95409     MBC  48910
# 95410     PRV  91320
# 95411     MCC  28409
#
# [95412 rows x 2 columns]

# %%
# now that we saved these columns in a different df we can drop them from the original dataframe

df.drop(["OSOURCE", "ZIP"], axis=1, inplace=True)

# %% [markdown]
# ### Identify columns that over 85% missing values

# %%
nan_columns85 = [i for i in df.columns if df[i].isna().sum() > 0.85*len(df)]

# %%
nan_columns85
# Out:
# ['NUMCHLD',
#  'RDATE_3',
#  'RDATE_4',
#  'RDATE_5',
#  'RDATE_6',
#  'RDATE_7',
#  'RDATE_10',
#  'RDATE_13',
#  'RDATE_15',
#  'RDATE_17',
#  'RDATE_20',
#  'RDATE_21',
#  'RDATE_23',
#  'RAMNT_3',
#  'RAMNT_4',
#  'RAMNT_5',
#  'RAMNT_6',
#  'RAMNT_7',
#  'RAMNT_10',
#  'RAMNT_13',
#  'RAMNT_15',
#  'RAMNT_17',
#  'RAMNT_20',
#  'RAMNT_21',
#  'RAMNT_23']

# %% [markdown]
# ### Remove those columns from the dataframe

# %%
df_drop = df_drop.append(df[['NUMCHLD',
 'RDATE_3',
 'RDATE_4',
 'RDATE_5',
 'RDATE_6',
 'RDATE_7',
 'RDATE_10',
 'RDATE_13',
 'RDATE_15',
 'RDATE_17',
 'RDATE_20',
 'RDATE_21',
 'RDATE_23',
 'RAMNT_3',
 'RAMNT_4',
 'RAMNT_5',
 'RAMNT_6',
 'RAMNT_7',
 'RAMNT_10',
 'RAMNT_13',
 'RAMNT_15',
 'RAMNT_17',
 'RAMNT_20',
 'RAMNT_21',
 'RAMNT_23']])

df_drop
# Out:
# C:\Users\lazar\AppData\Local\Temp\ipykernel_14584\1793610748.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_drop = df_drop.append(df[['NUMCHLD',
#       OSOURCE    ZIP  NUMCHLD  RDATE_3  RDATE_4  RDATE_5  RDATE_6  RDATE_7  \
# 0         GRI  61081      NaN      NaN      NaN      NaN      NaN      NaN
# 1         BOA  91326      NaN      NaN      NaN      NaN      NaN      NaN
# 2         AMH  27017      NaN      NaN      NaN      NaN      NaN      NaN
# 3         BRY  95953      NaN      NaN      NaN      NaN      NaN      NaN
# 4              33176      NaN      NaN      NaN      NaN      NaN      NaN
# ...       ...    ...      ...      ...      ...      ...      ...      ...
# 95407     NaN    NaN      NaN      NaN      NaN      NaN      NaN   9602.0
# 95408     NaN    NaN      1.0      NaN      NaN      NaN      NaN   9603.0
# ...

# %%
df.drop(
['NUMCHLD',
 'RDATE_3',
 'RDATE_4',
 'RDATE_5',
 'RDATE_6',
 'RDATE_7',
 'RDATE_10',
 'RDATE_13',
 'RDATE_15',
 'RDATE_17',
 'RDATE_20',
 'RDATE_21',
 'RDATE_23',
 'RAMNT_3',
 'RAMNT_4',
 'RAMNT_5',
 'RAMNT_6',
 'RAMNT_7',
 'RAMNT_10',
 'RAMNT_13',
 'RAMNT_15',
 'RAMNT_17',
 'RAMNT_20',
 'RAMNT_21',
 'RAMNT_23'], axis=1, inplace=True)

# %%
df #sanity check
# Our df is down to 454 from 481 after applying the above steps.
# Out:
#        ODATEDW  TCODE STATE MAILCODE PVASTATE   DOB NOEXCH RECINHSE RECP3  \
# 0         8901      0    IL                    3712      0
# 1         9401      1    CA                    5202      0
# 2         9001      1    NC                       0      0
# 3         8701      0    CA                    2801      0
# 4         8601      0    FL                    2001      0        X     X
# ...        ...    ...   ...      ...      ...   ...    ...      ...   ...
# 95407     9601      1    AK                       0      0
# 95408     9601      1    TX                    5001      0
# 95409     9501      1    MI                    3801      0              X
# 95410     8601      0    CA                    4005      0        X
# 95411     8801      2    NC                    1801      0        X
#
#       RECPGVG  ... TARGET_D HPHONE_D RFA_2R RFA_2F  RFA_2A MDMAUD_R MDMAUD_F  \
# 0              ...      0.0        0      L      4       E        X        X
# ...

# %% [markdown]
# ### Reduce the number of categories in the column GENDER. The column should only have either "M" for males, "F" for females, and "other" for all the rest.
#
# Note that there are a few null values in the column. We will first replace those null values using the code below:
#
# `print(categorical['GENDER'].value_counts())
# categorical['GENDER'] = categorical['GENDER'].fillna('F')`

# %%
# applying the code the was provided 

print(categorical['GENDER'].value_counts())
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
categorical['GENDER'] = categorical['GENDER'].fillna('F')

# %%
# this code does not seem to work properly for these 2957 values.

categorical['GENDER'].value_counts()
# Out:
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
# replacing seems to do the work though!

categorical['GENDER'] = categorical['GENDER'].replace(' ', 'F')


categorical['GENDER'].value_counts()
# Out:
# F    54234
# M    39094
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
# and now we can do the same for other gender values

categorical['GENDER'] = categorical['GENDER'].replace(['U', 'J', 'C', 'A'], 'other')

categorical['GENDER'].value_counts()
# Out:
# F        54234
# M        39094
# other     2084
# Name: GENDER, dtype: int64
